# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
MHZ = 1e6
fc = 20*MHZ
fs = 65*MHZ
f_clk = 100*MHZ
f_osc = fc*f_clk/fs
n = np.arange(1000)

# %%
seno = np.sin(2*np.pi*f_osc*n/f_clk)

# %%
t = n/fs
plt.plot(t, seno)
plt.xlim(0, 1e-6)
plt.grid()
